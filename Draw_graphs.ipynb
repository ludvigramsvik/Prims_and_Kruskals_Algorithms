# %% [markdown]
# ## Load a graph from Matrix

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)

matrix = np.loadtxt('Graphs/test_graph.txt', dtype=int)

G = nx.from_numpy_array(matrix)

nx.draw(G, with_labels=True, node_color='lightblue', edge_color='gray')
plt.show()

# %%
# Print edges
edges = G.edges()
print("Edges in the graph:", edges)
# Out:
# Edges in the graph: [(0, 5), (1, 2), (1, 6), (2, 5), (3, 6), (3, 7), (3, 8), (4, 6), (5, 7), (5, 9), (6, 7)]

# %% [markdown]
# ---
# ### Add random weight to the edges

# %%
# add random weights to edges
for u, v in G.edges():
    G[u][v]['weight'] = np.random.randint(1, 10)

# print edges with weights
print(G.edges(data=True))
# Out:
# [(0, 5, {'weight': 3}), (1, 2, {'weight': 7}), (1, 6, {'weight': 4}), (2, 5, {'weight': 9}), (3, 6, {'weight': 3}), (3, 7, {'weight': 5}), (3, 8, {'weight': 3}), (4, 6, {'weight': 7}), (5, 7, {'weight': 5}), (5, 9, {'weight': 9}), (6, 7, {'weight': 7})]

# %% [markdown]
# ---
# ### Print the graph with the weights

# %%
np.random.seed(42)
pos = nx.spring_layout(G, k=0.8, iterations=100)

# 3. Draw with slightly smaller nodes and fonts
nx.draw(G, pos, 
        with_labels=True, 
        node_color='lightblue', 
        edge_color='gray')

edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=7, bbox=dict(facecolor='white', edgecolor='none', alpha=1))
plt.show()

# %% [markdown]
# ---
# ### Save the new graph to file

# %%
new_matrix = nx.to_numpy_array(G)
np.savetxt('Graphs/test_graph_with_weights.txt', new_matrix, fmt='%d')
